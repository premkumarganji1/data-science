# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# '/home/premkumar/work files/data-science-learn/data-science/data-science-statistics'

# %%
df = pd.read_csv('/home/premkumar/work files/data-science-learn/data-science/data-sets/AB_NYC_2019.csv')
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
df.sort_values(by=['price'], ascending=False).head(3)
# Out:
#              id                                             name   host_id  \
# 9151    7003697              Furnished room in Astoria apartment  20582832
# 17692  13894339  Luxury 1 bedroom apt. -stunning Manhattan views   5143901
# 29238  22436899                              1-BR Lincoln Center  72390391
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 9151   Kathrine              Queens          Astoria  40.76810  -73.91651
# 17692      Erin            Brooklyn       Greenpoint  40.73260  -73.95739
# 29238    Jelena           Manhattan  Upper West Side  40.77213  -73.98665
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 9151      Private room  10000             100                  2  2016-02-13
# 17692  Entire home/apt  10000               5                  5  2017-07-27
# 29238  Entire home/apt  10000              30                  0         NaN
#
# ...

# %%
df.sort_values(by=['price']).head(1)
# Out:
#              id                                          name   host_id  \
# 25796  20639914  Cozy yet spacious private brownstone bedroom  86327101
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 25796   Adeyemi            Brooklyn  Bedford-Stuyvesant  40.68258  -73.91284
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 25796  Private room      0               1                 95  2019-06-23
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 25796               4.35                               6               222

# %%
df.price.sort_values(ascending=False).head(5)
# Out:
# 9151     10000
# 17692    10000
# 29238    10000
# 40433     9999
# 12342     9999
# Name: price, dtype: int64

# %%
df.price.isnull().values.any()
# Out:
# False

# %%
df.price.quantile(0.99)
# Out:
# 799.0

# %%
df[df.price > df.price.quantile(0.99)].head(2)
# Out:
#          id                                   name  host_id host_name  \
# 85    19601    perfect for a family or small group    74303    Maggie
# 496  174966  Luxury 2Bed/2.5Bath Central Park View   836168     Henry
#
#     neighbourhood_group     neighbourhood  latitude  longitude  \
# 85             Brooklyn  Brooklyn Heights  40.69723  -73.99268
# 496           Manhattan   Upper West Side  40.77350  -73.98697
#
#            room_type  price  minimum_nights  number_of_reviews last_review  \
# 85   Entire home/apt    800               1                 25  2016-08-04
# 496  Entire home/apt   2000              30                 30  2018-05-05
#
#      reviews_per_month  calculated_host_listings_count  availability_365
# 85                0.24                               1                 7
# 496               0.33                              11                 0

# %%
df_no_outliers = df[(df.price < df.price.quantile(0.99)) & (df.price != 0.0)]
df_no_outliers
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df_no_outliers.price.describe()
# Out:
# count    48392.000000
# mean       137.329145
# std        103.012234
# min         10.000000
# 25%         69.000000
# 50%        105.000000
# 75%        175.000000
# max        795.000000
# Name: price, dtype: float64
